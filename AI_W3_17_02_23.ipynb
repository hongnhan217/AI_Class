# %% [markdown]
# <a href="https://colab.research.google.com/github/hongnhan217/AI_Class/blob/main/AI_W3_17_02_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.DataFrame()

# %%
df['Name'] = ['Lemon','Apple','Banana']
df['Price'] = [5,8,7]
df['License'] = ['False','True','True']
#showdata
df
# Out:
#      Name  Price License
# 0   Lemon      5   False
# 1   Apple      8    True
# 2  Banana      7    True

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
list(df.columns)
# Out:
# ['Name', 'Price', 'License']

# %%
df.describe()
# Out:
#           Price
# count  3.000000
# mean   6.666667
# std    1.527525
# min    5.000000
# 25%    6.000000
# 50%    7.000000
# 75%    7.500000
# max    8.000000

# %%
df.loc[(df.Price == 5)]
# Out:
#     Name  Price License
# 0  Lemon      5   False

# %%
df.loc[(df.Name == "Apple") | (df.Price == 7)]
# Out:
#      Name  Price License
# 1   Apple      8    True
# 2  Banana      7    True

# %%
df.loc[(df.Name == "Apple") | (df.Price == 7), ['Name','License']]
# Out:
#      Name License
# 1   Apple    True
# 2  Banana    True

# %%
df.iloc[2]
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.iloc[[2]]
# Out:
#      Name  Price License
# 2  Banana      7    True

# %%
df.iloc[0:2]
# Out:
#     Name  Price License
# 0  Lemon      5   False
# 1  Apple      8    True

# %%
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: object

# %%
df.iloc[0:2,0:-1]
# Out:
#     Name  Price
# 0  Lemon      5
# 1  Apple      8

# %%
sum = df.Price.sum()
sum
# Out:
# 20

# %%
orange = pd.Series(['Orange',10,'True'],index=['Name','Price','License'])
df.append(orange,ignore_index=True)
# Out:
#      Name  Price License
# 0   Lemon      5   False
# 1   Apple      8    True
# 2  Banana      7    True
# 3  Orange     10    True

# %%
# append a column
df['Location'] = ['USA','VN','SIN']
df
# Out:
#      Name  Price License Location
# 0   Lemon      5   False      USA
# 1   Apple      8    True       VN
# 2  Banana      7    True      SIN

# %%
# delete a row
df.drop(2, axis=0).head(10)
# Out:
#     Name  Price License Location
# 0  Lemon      5   False      USA
# 1  Apple      8    True       VN

# %%
# delete a row
df.drop('Name', axis=1).head(10)
# Out:
#    Price License Location
# 0      5   False      USA
# 1      8    True       VN
# 2      7    True      SIN

# %%
# delete a column
df.drop('Location', axis=1).head()
# Out:
#      Name  Price License
# 0   Lemon      5   False
# 1   Apple      8    True
# 2  Banana      7    True

# %%
# replace
df['Price'].replace(5,7).head(5)
# Out:
# 0    7
# 1    8
# 2    7
# Name: Price, dtype: int64

# %%
# rename columns
df.rename(columns={'Price':'Cost'}).head()
# Out:
#      Name  Cost License Location
# 0   Lemon     5   False      USA
# 1   Apple     8    True       VN
# 2  Banana     7    True      SIN

# %%
# load library
import pandas as pd
# create url
url = 'http://winterolympicsmedals.com/medals.csv'
# load data
dataframe = pd.read_csv(url)
# dataframe = pd.read_csv(url,sep='/t')
# show data
dataframe.head(10)
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# ...

# %%
dataframe.shape
# Out:
# (2311, 8)

# %%
dataframe.info
# Out:
# <bound method DataFrame.info of       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
list(dataframe.columns)
# Out:
# ['Year',
#  'City',
#  'Sport',
#  'Discipline',
#  'NOC',
#  'Event',
#  'Event gender',
#  'Medal']

# %%
dataframe.describe()
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
dataframe.loc[(dataframe.Year>=2000)].head(20)
# Out:
#       Year            City      Sport       Discipline  NOC            Event  \
# 1825  2002  Salt Lake City    Skating   Short Track S.  AUS            1000m
# 1826  2002  Salt Lake City     Skiing   Freestyle Ski.  AUS          aerials
# 1827  2002  Salt Lake City   Biathlon         Biathlon  AUT             10km
# 1828  2002  Salt Lake City  Bobsleigh         Skeleton  AUT       individual
# 1829  2002  Salt Lake City       Luge             Luge  AUT          singles
# 1830  2002  Salt Lake City     Skiing    Alpine Skiing  AUT  alpine combined
# 1831  2002  Salt Lake City     Skiing    Alpine Skiing  AUT  alpine combined
# 1832  2002  Salt Lake City     Skiing    Alpine Skiing  AUT         downhill
# 1833  2002  Salt Lake City     Skiing    Alpine Skiing  AUT         downhill
# 1834  2002  Salt Lake City     Skiing    Alpine Skiing  AUT         downhill
# 1835  2002  Salt Lake City     Skiing    Alpine Skiing  AUT     giant slalom
# ...

# %%
dataframe.iloc[10:20]
# Out:
#     Year      City      Sport       Discipline  NOC                Event  \
# 10  1924  Chamonix    Skating    Speed skating  FIN                5000m
# 11  1924  Chamonix    Skating    Speed skating  FIN                5000m
# 12  1924  Chamonix    Skating    Speed skating  FIN                 500m
# 13  1924  Chamonix    Skating    Speed skating  FIN  combined (4 events)
# 14  1924  Chamonix    Skating    Speed skating  FIN  combined (4 events)
# 15  1924  Chamonix     Skiing  Cross Country S  FIN                 18km
# 16  1924  Chamonix   Biathlon         Biathlon  FRA      military patrol
# 17  1924  Chamonix    Curling          Curling  FRA              curling
# 18  1924  Chamonix    Skating   Figure skating  FRA                pairs
# 19  1924  Chamonix  Bobsleigh        Bobsleigh  GBR             four-man
#
#    Event gender   Medal
# 10            M    Gold
# 11            M  Silver
# 12            M  Bronze
# 13            M  Bronze
# 14            M    Gold
# ...

# %%
sum = dataframe.Year.sum()
sum
# Out:
# 4576616

# %%
Master = pd.Series([1940,'Tokio','5000m','Diamond'],index=['Year','City','Event','Medal'])
dataframe=dataframe.append(Master,ignore_index=True)

# %%
dataframe.loc[(dataframe.Medal=='Diamond')].head()
# Out:
#       Year   City Sport Discipline  NOC  Event Event gender    Medal
# 2311  1940  Tokio   NaN        NaN  NaN  5000m          NaN  Diamond

# %%
dataframe = dataframe.set_index(dataframe['NOC'])
dataframe.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# ...

# %%
dataframe.loc['USA']
# Out:
#      Year        City       Sport      Discipline  NOC                 Event  \
# NOC
# USA  1924    Chamonix  Ice Hockey      Ice Hockey  USA            ice hockey
# USA  1924    Chamonix     Skating  Figure skating  USA            individual
# USA  1924    Chamonix     Skating   Speed skating  USA                  500m
# USA  1924    Chamonix      Skiing     Ski Jumping  USA  K90 individual (70m)
# USA  1928  St. Moritz   Bobsleigh       Bobsleigh  USA              five-man
# ..    ...         ...         ...             ...  ...                   ...
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
#
#     Event gender   Medal
# NOC
# ...

# %%
dataframe[(dataframe['Year']>=1990)&(dataframe['Year']<=2006) & (dataframe['NOC']=='USA')&(dataframe['Event gender']=='W')&(dataframe['Medal']=='Gold')].head(10)
# Out:
#      Year         City       Sport      Discipline  NOC       Event  \
# NOC
# USA  1992  Albertville     Skating  Figure skating  USA  individual
# USA  1992  Albertville     Skating  Short Track S.  USA        500m
# USA  1992  Albertville     Skating   Speed skating  USA       1000m
# USA  1992  Albertville     Skating   Speed skating  USA        500m
# USA  1992  Albertville      Skiing  Freestyle Ski.  USA      moguls
# USA  1994  Lillehammer     Skating  Short Track S.  USA        500m
# USA  1994  Lillehammer     Skating   Speed skating  USA       1000m
# USA  1994  Lillehammer     Skating   Speed skating  USA        500m
# USA  1994  Lillehammer      Skiing   Alpine Skiing  USA     super-G
# USA  1998       Nagano  Ice Hockey      Ice Hockey  USA  ice hockey
#
#     Event gender Medal
# NOC
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# ...

# %%
df=dataframe

# %%
df['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
df.count()
# Out:
# Year            2312
# City            2312
# Sport           2311
# Discipline      2311
# NOC             2311
# Event           2312
# Event gender    2311
# Medal           2312
# dtype: int64

# %%
df['NOC'].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK', nan],
#       dtype=object)

# %%
df.drop('NOC', axis=1).head(10)
# Out:
#      Year      City       Sport      Discipline            Event Event gender  \
# NOC
# AUT  1924  Chamonix     Skating  Figure skating       individual            M
# AUT  1924  Chamonix     Skating  Figure skating       individual            W
# AUT  1924  Chamonix     Skating  Figure skating            pairs            X
# BEL  1924  Chamonix   Bobsleigh       Bobsleigh         four-man            M
# CAN  1924  Chamonix  Ice Hockey      Ice Hockey       ice hockey            M
# FIN  1924  Chamonix    Biathlon        Biathlon  military patrol            M
# FIN  1924  Chamonix     Skating  Figure skating            pairs            X
# FIN  1924  Chamonix     Skating   Speed skating           10000m            M
# FIN  1924  Chamonix     Skating   Speed skating           10000m            M
# FIN  1924  Chamonix     Skating   Speed skating            1500m            M
#
#       Medal
# NOC
# AUT  Silver
# AUT    Gold
# AUT    Gold
# BEL  Bronze
# CAN    Gold
# FIN  Silver
# ...

# %%
df.drop(df.columns[2:4], axis=1).head(10)
# Out:
#      Year      City  NOC            Event Event gender   Medal
# NOC
# AUT  1924  Chamonix  AUT       individual            M  Silver
# AUT  1924  Chamonix  AUT       individual            W    Gold
# AUT  1924  Chamonix  AUT            pairs            X    Gold
# BEL  1924  Chamonix  BEL         four-man            M  Bronze
# CAN  1924  Chamonix  CAN       ice hockey            M    Gold
# FIN  1924  Chamonix  FIN  military patrol            M  Silver
# FIN  1924  Chamonix  FIN            pairs            X  Silver
# FIN  1924  Chamonix  FIN           10000m            M    Gold
# FIN  1924  Chamonix  FIN           10000m            M  Silver
# FIN  1924  Chamonix  FIN            1500m            M    Gold

# %%
data = df

# %%
data[data['NOC']!='CAN'].head(10)
# Out:
#      Year      City      Sport      Discipline  NOC            Event  \
# NOC
# AUT  1924  Chamonix    Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix    Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix    Skating  Figure skating  AUT            pairs
# BEL  1924  Chamonix  Bobsleigh       Bobsleigh  BEL         four-man
# FIN  1924  Chamonix   Biathlon        Biathlon  FIN  military patrol
# FIN  1924  Chamonix    Skating  Figure skating  FIN            pairs
# FIN  1924  Chamonix    Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix    Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix    Skating   Speed skating  FIN            1500m
# FIN  1924  Chamonix    Skating   Speed skating  FIN            5000m
#
#     Event gender   Medal
# NOC
# AUT            M  Silver
# AUT            W    Gold
# AUT            X    Gold
# BEL            M  Bronze
# FIN            M  Silver
# FIN            X  Silver
# ...

# %%
data = pd.read_csv(url)
data.groupby('NOC').head(10)
# Out:
#       Year      City       Sport       Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT       individual
# 1     1924  Chamonix     Skating   Figure skating  AUT       individual
# 2     1924  Chamonix     Skating   Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...              ...  ...              ...
# 2231  2006     Turin    Biathlon         Biathlon  POL  15km mass start
# 2232  2006     Turin      Skiing  Cross Country S  POL             30km
# 2269  2006     Turin      Skiing        Snowboard  SVK  Snowboard Cross
# 2284  2006     Turin    Biathlon         Biathlon  UKR            7.5km
# 2285  2006     Turin     Skating   Figure skating  UKR      ice dancing
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
data.groupby('NOC').count()
# Out:
#      Year  City  Sport  Discipline  Event  Event gender  Medal
# NOC
# AUS     6     6      6           6      6             6      6
# AUT   185   185    185         185    185           185    185
# BEL     5     5      5           5      5             5      5
# BLR     6     6      6           6      6             6      6
# BUL     6     6      6           6      6             6      6
# CAN   119   119    119         119    119           119    119
# CHN    33    33     33          33     33            33     33
# CRO     7     7      7           7      7             7      7
# CZE    10    10     10          10     10            10     10
# DEN     1     1      1           1      1             1      1
# ESP     2     2      2           2      2             2      2
# EST     6     6      6           6      6             6      6
# EUA    19    19     19          19     19            19     19
# EUN    23    23     23          23     23            23     23
# ...

# %%
data = pd.read_csv(url)

# %%
# apply a function
def uppercase(x):
  return x.upper()
data['Event'].apply(uppercase)[0:2311]
# Out:
# 0            INDIVIDUAL
# 1            INDIVIDUAL
# 2                 PAIRS
# 3              FOUR-MAN
# 4            ICE HOCKEY
#              ...
# 2306          HALF-PIPE
# 2307          HALF-PIPE
# 2308          HALF-PIPE
# 2309    SNOWBOARD CROSS
# 2310    SNOWBOARD CROSS
# Name: Event, Length: 2311, dtype: object

# %%
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...
