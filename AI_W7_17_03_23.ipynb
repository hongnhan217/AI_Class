# %% [markdown]
# <a href="https://colab.research.google.com/github/hongnhan217/AI_Class/blob/main/AI_W7_17_03_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('mtcars.csv')
data.head()
# Out:
#           Unnamed: 0   mpg   disp   hp     wt
# 0          Mazda RX4  21.0  160.0  110  2.620
# 1      Mazda RX4 Wag  21.0  160.0  110  2.875
# 2         Datsun 710  22.8  108.0   93  2.320
# 3     Hornet 4 Drive  21.4  258.0  110  3.215
# 4  Hornet Sportabout  18.7  360.0  175  3.440

# %%
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data["wt"]),y=data["mpg"])
print("he so intercept",model.intercept_)
print("he so coeffent",model.coef_)
model.score(X=pd.DataFrame(data["wt"]),y=data["mpg"])

y_pred = model.predict(X=pd.DataFrame(data["wt"]))
# Out:
# he so intercept 37.28512616734204
# he so coeffent [-5.34447157]

# %%
data.plot(kind = "scatter",x="wt",y="mpg",figsize=(9,9),
         color="black",xlim=(0,7))
plt.plot(data['wt'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X=pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y = data["mpg"])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X,y = data["mpg"]))
# Out:
# intercept cua mo hinh 49.93081094945181
# coeffent cua mo hinh [-13.38033708   1.17108689]
# do chinh xac cua mo hinh 0.8190613581384094

# %%
import numpy as np
range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X=X_range)
data.plot(kind='scatter', x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X=pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,
                data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,
                data['wt']**9,data['wt']**10,data['wt']**11]).T
model.fit(X,y = data["mpg"])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X,y = data["mpg"]))
# Out:
# intercept cua mo hinh -231415.3012044087
# coeffent cua mo hinh [ 9.15190229e+05 -1.60853068e+06  1.65815938e+06 -1.11378394e+06
#   5.11894008e+05 -1.64309153e+05  3.68501885e+04 -5.66220383e+03
#   5.68057758e+02 -3.35128769e+01  8.81444412e-01]
# do chinh xac cua mo hinh 0.8757492427094143

# %%
import numpy as np
range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10,range**11]).T
y_pred = model.predict(X=X_range)
data.plot(kind='scatter', x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='wt', ylabel='mpg'>

# %%
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp']],y=data['mpg'])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X=data.loc[:,['wt','hp']],y=data['mpg']))
# Out:
# intercept cua mo hinh 37.227270116447215
# coeffent cua mo hinh [-3.87783074 -0.03177295]
# do chinh xac cua mo hinh 0.8267854518827914

# %%
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp','disp']],y=data['mpg'])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X=data.loc[:,['wt','hp','disp']],y=data['mpg']))
# Out:
# intercept cua mo hinh 37.10550526903184
# coeffent cua mo hinh [-3.80089058e+00 -3.11565508e-02 -9.37009081e-04]
# do chinh xac cua mo hinh 0.8268361424946447

# %%
import pandas as pd
data = pd.read_csv('50_Startups.csv')
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data["R&D Spend"]),y=data["Profit"])
print("he so intercept",model.intercept_)
print("he so coeffent",model.coef_)
print(model.score(X=pd.DataFrame(data["R&D Spend"]),y=data["Profit"]))

y_pred = model.predict(X=pd.DataFrame(data["R&D Spend"]))
# Out:
# he so intercept 49032.89914125215
# he so coeffent [0.85429137]
# 0.9465353160804393

# %%
data.plot(kind = "scatter",x="R&D Spend",y="Profit",figsize=(9,9),
         color="black",xlim=(0,7))
plt.plot(data['R&D Spend'],y_pred,color='blue')

# %%
model = linear_model.LinearRegression()
X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3]).T
model.fit(X,y = data["Profit"])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X,y = data["Profit"]))
# Out:
# intercept cua mo hinh 43108.76756818297
# coeffent cua mo hinh [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# do chinh xac cua mo hinh 0.9540709421464032

# %%
import numpy as np
range = np.arange(0,8,0.1)
X_range = pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict(X=X_range)
data.plot(kind='scatter', x='R&D Spend',y='Profit',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['R&D Spend','Administration']],y=data['Profit'])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X=data.loc[:,['R&D Spend','Administration']],y=data['Profit']))
# Out:
# intercept cua mo hinh 54886.62062756297
# coeffent cua mo hinh [ 0.86211798 -0.05299543]
# do chinh xac cua mo hinh 0.9478129385009173

# %%
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['R&D Spend','Administration','Marketing Spend']],y=data['Profit'])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X=data.loc[:,['R&D Spend','Administration','Marketing Spend']],y=data['Profit']))
# Out:
# intercept cua mo hinh 50122.19298986524
# coeffent cua mo hinh [ 0.80571505 -0.02681597  0.02722806]
# do chinh xac cua mo hinh 0.9507459940683246

# %%
data = pd.read_csv('Advertising.csv')
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data["sales"]),y=data["TV"])
print("he so intercept",model.intercept_)
print("he so coeffent",model.coef_)
print(model.score(X=pd.DataFrame(data["sales"]),y=data["TV"]))

y_pred = model.predict(X=pd.DataFrame(data["sales"]))
# Out:
# he so intercept -33.45022776511354
# he so coeffent [12.87165112]
# 0.6118750508500711

# %%
data.plot(kind = "scatter",x="sales",y="TV",figsize=(9,9),
         color="black",xlim=(0,30))
plt.plot(data['sales'],y_pred,color='blue')

# %%
data.plot(kind = "scatter",x="sales",y="TV",figsize=(9,9),
         color="black",xlim=(22,30))
plt.plot(data['sales'],y_pred,color='blue')

# %%
model = linear_model.LinearRegression()
X=pd.DataFrame([data['sales'],data['sales']**2]).T
model.fit(X,y = data["TV"])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X,y = data["TV"]))
# Out:
# intercept cua mo hinh -132.36742019420328
# coeffent cua mo hinh [27.85355059 -0.49690844]
# do chinh xac cua mo hinh 0.6466470605819978

# %%
model = linear_model.LinearRegression()
X=pd.DataFrame([data['sales'],data['sales']**2,
                data['sales']**3,data['sales']**4,
                data['sales']**5,data['sales']**6,
                data['sales']**7]).T
model.fit(X,y = data["TV"])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X,y = data["TV"]))
# Out:
# intercept cua mo hinh -300.82316524004773
# coeffent cua mo hinh [ 3.26132033e+02 -1.16114048e+02  1.91358424e+01 -1.62524934e+00
#   7.43946373e-02 -1.74795896e-03  1.65604236e-05]
# do chinh xac cua mo hinh 0.6788375238397134

# %%
model = linear_model.LinearRegression()
X=pd.DataFrame([data['sales'],data['sales']**2,
                data['sales']**3,data['sales']**4,
                data['sales']**5,data['sales']**6,
                data['sales']**7,data['sales']**8,
                data['sales']**9,data['sales']**10,data['sales']**11]).T
model.fit(X,y = data["TV"])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X,y = data["TV"]))
# Out:
# intercept cua mo hinh -25.772495888489658
# coeffent cua mo hinh [ 1.04264894e+00  3.58142868e+00  4.92314878e+00 -3.05199864e+00
#   6.88203077e-01 -8.10708968e-02  5.57734480e-03 -2.31472861e-04
#   5.67281650e-06 -7.48154889e-08  4.02098355e-10]
# do chinh xac cua mo hinh 0.6850146848775904

# %%
import numpy as np
range = np.arange(1.5,27.5,0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10,range**11]).T
y_pred = model.predict(X=X_range)
data.plot(kind='scatter', x='sales',y='TV',figsize=(9,9),color='black',xlim=(0,29))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['TV','radio']],y=data['sales'])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X=data.loc[:,['TV','radio']],y=data['sales']))
# Out:
# intercept cua mo hinh 2.9210999124051362
# coeffent cua mo hinh [0.04575482 0.18799423]
# do chinh xac cua mo hinh 0.8971942610828957

# %%
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['TV','radio','newspaper']],y=data['sales'])
print('intercept cua mo hinh',model.intercept_)
print('coeffent cua mo hinh',model.coef_)
print('do chinh xac cua mo hinh',model.score(X=data.loc[:,['TV','radio','newspaper']],y=data['sales']))
# Out:
# intercept cua mo hinh 2.938889369459412
# coeffent cua mo hinh [ 0.04576465  0.18853002 -0.00103749]
# do chinh xac cua mo hinh 0.8972106381789522

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('insurance.csv')
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.sample(5)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 27     55  female  32.775         2     no  northwest  12268.63225
# 1033   18    male  21.565         0    yes  northeast  13747.87235
# 49     36    male  35.200         1    yes  southeast  38709.17600
# 654    59  female  35.200         0     no  southeast  12244.53100
# 207    35    male  27.740         2    yes  northeast  20984.09360

# %%
data.hist()
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
print(data['sex'].value_counts())
sns.countplot(x='sex',data=data)
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
# <Axes: xlabel='sex', ylabel='count'>

# %%
print(data['smoker'].value_counts())
sns.countplot(x='smoker',data=data)
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64
# <Axes: xlabel='smoker', ylabel='count'>

# %%
print(data['region'].value_counts())
sns.countplot(x='region',data=data)
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64
# <Axes: xlabel='region', ylabel='count'>

# %%
corr = data.corr()
sns.heatmap(corr,cmap='Wistia', annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data["age"]),y=data["charges"])
print("he so intercept",model.intercept_)
print("he so coeffent",model.coef_)
model.score(X=pd.DataFrame(data["age"]),y=data["charges"])
print(model.score(X=pd.DataFrame(data["age"]),y=data["charges"]))

y_pred = model.predict(X=pd.DataFrame(data["age"]))
# Out:
# he so intercept 3165.885006063021
# he so coeffent [257.72261867]
# 0.08940589967885804
